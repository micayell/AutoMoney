# %% [markdown]
# # 1. 준비
# ### (1) 패키지 import

# %%
# 패키지 import
# !pip install matplotlib ta pyarrow fastparquet
import pandas as pd
import matplotlib.pyplot as plt
import ta
# Out:
# Requirement already satisfied: matplotlib in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (3.9.4)
# Requirement already satisfied: ta in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (0.11.0)
# Requirement already satisfied: pyarrow in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (21.0.0)
# Requirement already satisfied: fastparquet in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (2024.11.0)
# Requirement already satisfied: contourpy>=1.0.1 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from matplotlib) (1.3.0)
# Requirement already satisfied: cycler>=0.10 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from matplotlib) (0.12.1)
# Requirement already satisfied: fonttools>=4.22.0 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from matplotlib) (4.60.2)
# Requirement already satisfied: kiwisolver>=1.3.1 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from matplotlib) (1.4.7)
# Requirement already satisfied: numpy>=1.23 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from matplotlib) (2.0.2)
# Requirement already satisfied: packaging>=20.0 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from matplotlib) (25.0)
# Requirement already satisfied: pillow>=8 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from matplotlib) (11.3.0)
# Requirement already satisfied: pyparsing>=2.3.1 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from matplotlib) (3.3.1)
# Requirement already satisfied: python-dateutil>=2.7 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from matplotlib) (2.9.0.post0)
# Requirement already satisfied: importlib-resources>=3.2.0 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from matplotlib) (6.5.2)
# Requirement already satisfied: pandas in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from ta) (2.3.3)
# Requirement already satisfied: cramjam>=2.3 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from fastparquet) (2.11.0)
# Requirement already satisfied: fsspec in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from fastparquet) (2025.10.0)
# Requirement already satisfied: zipp>=3.1.0 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from importlib-resources>=3.2.0->matplotlib) (3.23.0)
# Requirement already satisfied: pytz>=2020.1 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from pandas->ta) (2025.2)
# Requirement already satisfied: tzdata>=2022.7 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from pandas->ta) (2025.3)
# Requirement already satisfied: six>=1.5 in c:\users\kimchangju\desktop\automoney\강의자료\.venv\lib\site-packages (from python-dateutil>=2.7->matplotlib) (1.17.0)

# %% [markdown]
# ### (2) 데이터 불러오기

# %%
# 데이터 불러오기

d = pd.read_parquet('005930.parquet')

# %% [markdown]
# ### (3) 데이터 준비

# %%
# 필요한 데이터 컬럼 생성

# 오늘 포함 과거 5일 종가 중 최고값
d['5d_max'] = d.rolling(5)['close'].max()

# 오늘 포함 과거 5일 종가 중 최저값
d['5d_min'] = d.rolling(5)['close'].min() 

# 전일 종가
d['last_1d_close'] = d['close'].shift(1) 

# 20일 이동평균
d['20d_mean'] = d.rolling(20)['close'].mean()

# %% [markdown]
# ### (4) 매매 시그널 생성

# %%
# 종가가 5일 최저가이고, 20일 이동평균보다 낮은 시점만 뽑기
buy = d[(d['close'] == d['5d_min']) & (d['close'] < d['20d_mean'])]

# %%
buy
# Out:
#      timestamp  ticker     open     high      low    close      volume  \
# 19    20100129  005930  16000.0  16020.0  15600.0  15680.0  22864250.0
# 20    20100201  005930  15680.0  15700.0  15300.0  15540.0  25052100.0
# 21    20100202  005930  15800.0  15800.0  15400.0  15440.0  19690150.0
# 24    20100205  005930  15160.0  15220.0  14940.0  15000.0  25751700.0
# 25    20100208  005930  14940.0  15080.0  14820.0  14960.0  21980400.0
# ...        ...     ...      ...      ...      ...      ...         ...
# 3524  20240416  005930  81200.0  81300.0  79400.0  80000.0  31949845.0
# 3525  20240417  005930  80700.0  80800.0  78900.0  78900.0  22611631.0
# 3527  20240419  005930  78300.0  78700.0  76300.0  77600.0  31317563.0
# 3528  20240422  005930  77400.0  77500.0  75100.0  76100.0  30469477.0
# 3529  20240423  005930  76400.0  76800.0  75500.0  75500.0  18717699.0
#
#        5d_max   5d_min  last_1d_close  20d_mean
# 19    16840.0  15680.0        16160.0   16402.0
# 20    16300.0  15540.0        15680.0   16370.0
# 21    16160.0  15440.0        15540.0   16320.0
# 24    15540.0  15000.0        15520.0   16148.0
# 25    15540.0  14960.0        15000.0   16099.0
# ...       ...      ...            ...       ...
# 3524  84100.0  80000.0        82200.0   81400.0
# 3525  84100.0  78900.0        80000.0   81705.0
# 3527  82200.0  77600.0        79600.0   81755.0
# 3528  80000.0  76100.0        77600.0   81615.0
# 3529  79600.0  75500.0        76100.0   81480.0
#
# [723 rows x 11 columns]

# %% [markdown]
# ---
# # 2. 분석

# %% [markdown]
# ### (1) 매수 시그널 plotting

# %%
# plt.plot을 활용해 주가 그래프 출력

plt.figure(figsize=(15,8))
plt.plot(d['close'])

# %%
# 주가 그래프에 매수 타점 표시

plt.figure(figsize=(15,8))
plt.plot(d['close'])
plt.scatter(buy.index,buy['close'],c='r')

# %%
# 최근 300일만 뽑아 매수 타점 표시

d_sample = d.iloc[-300:]
buy_sample = d_sample[(d_sample['close'] == d_sample['5d_min']) & (d_sample['close'] < d_sample['20d_mean'])]

plt.figure(figsize=(15,8))
plt.plot(d_sample['close'])
plt.scatter(buy_sample.index,buy_sample['close'],c='r')
